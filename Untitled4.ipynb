# %% [markdown]
# <a href="https://colab.research.google.com/github/R0h1ta/ML-with-Flask/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Data with missing values
data = {
    'Age': [25, None, 30, 35, None, 4.5],
    'Height': [5.5, 6.1, 5.9, None, 5.7, 6.2],
    'HelmetStatus': [1, None, 1, 0, 1, 1],
    'Gender': ['M', 'F', 'M', 'None', 'F', 'M'],  # 'None' as a string
    'Experience': [2, 4, 6, 1, None, None]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame with Missing values:")
print(df)

# Creating copies of the original DataFrame
df_filled_mean = df.copy()
df_filled_median = df.copy()
df_filled_mode = df.copy()

# Filling missing values with mean for 'Age', 'Height', and 'Experience'
df_filled_mean['Age'].fillna(df['Age'].mean(), inplace=True)
df_filled_mean['Height'].fillna(df['Height'].mean(), inplace=True)
df_filled_mean['Experience'].fillna(df['Experience'].mean(), inplace=True)

# Filling missing values with median for 'Age', 'Height', and 'Experience'
df_filled_median['Age'].fillna(df['Age'].median(), inplace=True)
df_filled_median['Height'].fillna(df['Height'].median(), inplace=True)
df_filled_median['Experience'].fillna(df['Experience'].median(), inplace=True)

# Filling missing values with mode for 'HelmetStatus' and 'Gender'
df_filled_mode['HelmetStatus'].fillna(df['HelmetStatus'].mode()[0], inplace=True)

# Handling the 'None' string in the 'Gender' column
df_filled_mode['Gender'] = df['Gender'].replace('None', None)
df_filled_mode['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# Display the DataFrames after imputation
print("\nDataFrame after filling with Mean:")
print(df_filled_mean)

print("\nDataFrame after filling with Median:")
print(df_filled_median)

print("\nDataFrame after filling with Mode:")
print(df_filled_mode)
# Out:
# Original DataFrame with Missing values:
#     Age  Height  HelmetStatus Gender  Experience
# 0  25.0     5.5           1.0      M         2.0
# 1   NaN     6.1           NaN      F         4.0
# 2  30.0     5.9           1.0      M         6.0
# 3  35.0     NaN           0.0   None         1.0
# 4   NaN     5.7           1.0      F         NaN
# 5   4.5     6.2           1.0      M         NaN
#
# DataFrame after filling with Mean:
#       Age  Height  HelmetStatus Gender  Experience
# 0  25.000    5.50           1.0      M        2.00
# 1  23.625    6.10           NaN      F        4.00
# 2  30.000    5.90           1.0      M        6.00
# 3  35.000    5.88           0.0   None        1.00
# 4  23.625    5.70           1.0      F        3.25
# 5   4.500    6.20           1.0      M        3.25
#
# DataFrame after filling with Median:
#     Age  Height  HelmetStatus Gender  Experience
# 0  25.0     5.5           1.0      M         2.0
# ...
